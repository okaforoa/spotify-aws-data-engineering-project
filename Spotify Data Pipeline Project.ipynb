# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\ookafor\appdata\local\anaconda3\lib\site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\ookafor\appdata\local\anaconda3\lib\site-packages (from spotipy) (4.5.5)
# Requirement already satisfied: requests>=2.25.0 in c:\users\ookafor\appdata\local\anaconda3\lib\site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: six>=1.15.0 in c:\users\ookafor\appdata\local\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\ookafor\appdata\local\anaconda3\lib\site-packages (from spotipy) (1.26.14)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\ookafor\appdata\local\anaconda3\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ookafor\appdata\local\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ookafor\appdata\local\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ookafor\appdata\local\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.12.7)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="", client_secret="")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbLRQDuF5jeBp"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2023-06-02T10:08:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#       'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#       'id': '0XeEobZplHxzM9QzFQWLiR',
#       'name': 'Eslabon Armado',
#       'type': 'artist',
#       'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'},
#     'href': 'https://api.spotify.com/v1/albums/5aDEezKnOqyQo0qvTFhpkM',
#     'id': '5aDEezKnOqyQo0qvTFhpkM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dfddf1cb31b85a6d28b7d91f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dfddf1cb31b85a6d28b7d91f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dfddf1cb31b85a6d28b7d91f',
#       'width': 64}],
#     'name': 'DESVELADO',
#     'release_date': '2023-04-28',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5aDEezKnOqyQo0qvTFhpkM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#      'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#      'id': '0XeEobZplHxzM9QzFQWLiR',
#      'name': 'Eslabon Armado',
#      'type': 'artist',
#      'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#      'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#      'id': '12GqGscKJx3aE4t07u7eVZ',
#      'name': 'Peso Pluma',
#      'type': 'artist',
#      'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 165671,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USE7D2300007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3qQbCzHBycnDpGskqOWY0E'},
#    'href': 'https://api.spotify.com/v1/tracks/3qQbCzHBycnDpGskqOWY0E',
#    'id': '3qQbCzHBycnDpGskqOWY0E',
#    'is_local': False,
#    'name': 'Ella Baila Sola',
#    'popularity': 92,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5d39f3e17f1e20e2711d033001e48b8d4249b992?cid=feff654b2685484ea84ba4c1be608611',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:3qQbCzHBycnDpGskqOWY0E'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-02T10:08:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#       'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#       'id': '4oUHIQIBe0LHzYfvXNW4QM',
#       'name': 'Morgan Wallen',
#       'type': 'artist',
#       'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6i7mF7whyRJuLJ4ogbH2wh'},
#     'href': 'https://api.spotify.com/v1/albums/6i7mF7whyRJuLJ4ogbH2wh',
#     'id': '6i7mF7whyRJuLJ4ogbH2wh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273705079df9a25a28b452c1fc9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02705079df9a25a28b452c1fc9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851705079df9a25a28b452c1fc9',
#       'width': 64}],
#     'name': 'One Thing At A Time',
#     'release_date': '2023-03-03',
#     'release_date_precision': 'day',
#     'total_tracks': 36,
#     'type': 'album',
#     'uri': 'spotify:album:6i7mF7whyRJuLJ4ogbH2wh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#      'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#      'id': '4oUHIQIBe0LHzYfvXNW4QM',
#      'name': 'Morgan Wallen',
#      'type': 'artist',
#      'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 163854,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12300802'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7K3BhSpAxZBznislvUMVtn'},
#    'href': 'https://api.spotify.com/v1/tracks/7K3BhSpAxZBznislvUMVtn',
#    'id': '7K3BhSpAxZBznislvUMVtn',
#    'is_local': False,
#    'name': 'Last Night',
#    'popularity': 89,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7K3BhSpAxZBznislvUMVtn'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-02T10:08:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#       'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#       'id': '3hcs9uc56yIGFCSy9leWe7',
#       'name': 'Lil Durk',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6ciIG1XKTlVIn0Yl8rvsce'},
#     'href': 'https://api.spotify.com/v1/albums/6ciIG1XKTlVIn0Yl8rvsce',
#     'id': '6ciIG1XKTlVIn0Yl8rvsce',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736234c2c6d4bb935839ac4719',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026234c2c6d4bb935839ac4719',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516234c2c6d4bb935839ac4719',
#       'width': 64}],
#     'name': 'Almost Healed',
#     'release_date': '2023-05-26',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:6ciIG1XKTlVIn0Yl8rvsce'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#      'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#      'id': '3hcs9uc56yIGFCSy9leWe7',
#      'name': 'Lil Durk',
#      'type': 'artist',
#      'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
#      'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#      'id': '6l3HvQ5sa6mXTsMTB19rO5',
#      'name': 'J. Cole',
#      'type': 'artist',
#      'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 223878,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USQX92302957'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6T7FXSuXykeGktMLGp8WgE'},
#    'href': 'https://api.spotify.com/v1/tracks/6T7FXSuXykeGktMLGp8WgE',
#    'id': '6T7FXSuXykeGktMLGp8WgE',
#    'is_local': False,
#    'name': 'All My Life (feat. J. Cole)',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/736c0ff37c1b6b7ca182ea6e78db36163e5e6eae?cid=feff654b2685484ea84ba4c1be608611',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6T7FXSuXykeGktMLGp8WgE'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-02T10:08:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5gCcb5fsSb6w5K8SyJrgtB'},
#     'href': 'https://api.spotify.com/v1/albums/5gCcb5fsSb6w5K8SyJrgtB',
#     'id': '5gCcb5fsSb6w5K8SyJrgtB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ab5c9cd818ad6ed3e9b79cd1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ab5c9cd818ad6ed3e9b79cd1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ab5c9cd818ad6ed3e9b79cd1',
#       'width': 64}],
#     'name': 'WHERE SHE GOES',
#     'release_date': '2023-05-18',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5gCcb5fsSb6w5K8SyJrgtB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 231704,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QM6P42334528'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7ro0hRteUMfnOioTFI5TG1'},
#    'href': 'https://api.spotify.com/v1/tracks/7ro0hRteUMfnOioTFI5TG1',
#    'id': '7ro0hRteUMfnOioTFI5TG1',
#    'is_local': False,
#    'name': 'WHERE SHE GOES',
#    'popularity': 95,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b9b7e4c982b33ee23c4867f7a3025e3598c35760?cid=feff654b2685484ea84ba4c1be608611',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7ro0hRteUMfnOioTFI5TG1'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-02T10:08:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#       'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#       'id': '6XkjpgcEsYab502Vr1bBeW',
#       'name': 'Grupo Frontera',
#       'type': 'artist',
#       'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7aGzSSUD8S6IhPCsZSiuMT'},
#     'href': 'https://api.spotify.com/v1/albums/7aGzSSUD8S6IhPCsZSiuMT',
#     'id': '7aGzSSUD8S6IhPCsZSiuMT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273716c0b0ad51594ff788b5f06',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02716c0b0ad51594ff788b5f06',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851716c0b0ad51594ff788b5f06',
#       'width': 64}],
#     'name': 'un x100to',
#     'release_date': '2023-04-17',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7aGzSSUD8S6IhPCsZSiuMT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#      'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#      'id': '6XkjpgcEsYab502Vr1bBeW',
#      'name': 'Grupo Frontera',
#      'type': 'artist',
#      'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 194563,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM6N22311285'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6pD0ufEQq0xdHSsRbg9LBK'},
#    'href': 'https://api.spotify.com/v1/tracks/6pD0ufEQq0xdHSsRbg9LBK',
#    'id': '6pD0ufEQq0xdHSsRbg9LBK',
#    'is_local': False,
#    'name': 'un x100to',
#    'popularity': 100,
#    'preview_url': 'https://p.scdn.co/mp3-preview/15117af933a505dd75ecd33d15f2d4d3e13bdf9a?cid=feff654b2685484ea84ba4c1be608611',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6pD0ufEQq0xdHSsRbg9LBK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-02T10:08:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#       'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#       'id': '7tYKF4w9nC0nq9CsPZTHyP',
#       'name': 'SZA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#     'href': 'https://api.spotify.com/v1/albums/1nrVofqDRs7cpWXJ49qTnP',
#     'id': '1nrVofqDRs7cpWXJ49qTnP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730c471c36970b9406233842a5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020c471c36970b9406233842a5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510c471c36970b9406233842a5',
#       'width': 64}],
#     'name': 'SOS',
#     'release_date': '2022-12-08',
#     'release_date_precision': 'day',
#     'total_tracks': 23,
#     'type': 'album',
#     'uri': 'spotify:album:1nrVofqDRs7cpWXJ49qTnP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#      'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#      'id': '7tYKF4w9nC0nq9CsPZTHyP',
#      'name': 'SZA',
#      'type': 'artist',
#      'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 153946,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC12204584'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1Qrg8KqiBpW07V7PNxwwwL'},
#    'href': 'https://api.spotify.com/v1/tracks/1Qrg8KqiBpW07V7PNxwwwL',
#    'id': '1Qrg8KqiBpW07V7PNxwwwL',
#    'is_local': False,
#    'name': 'Kill Bill',
#    'popularity': 94,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4bd2dc84016f3743add7eea8b988407b1b900672?cid=feff654b2685484ea84ba4c1be608611',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1Qrg8KqiBpW07V7PNxwwwL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-02T10:08:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#       'href': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF',
#       'id': '4V8LLVI7PbaPR0K2TGSxFF',
#       'name': 'Tyler, The Creator',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8LLVI7PbaPR0K2TGSxFF'}],
#     'available_markets': ['AD',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KZ',
#      'LA',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'RO',
#      'RS',
#      'RW',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2nkto6YNI4rUYTLqEwWJ3o'},
#     'href': 'https://api.spotify.com/v1/albums/2nkto6YNI4rUYTLqEwWJ3o',
#     'id': '2nkto6YNI4rUYTLqEwWJ3o',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738940ac99f49e44f59e6f7fb3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028940ac99f49e44f59e6f7fb3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518940ac99f49e44f59e6f7fb3',
#       'width': 64}],
#     'name': 'Flower Boy',
#     'release_date': '2017-07-21',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:2nkto6YNI4rUYTLqEwWJ3o'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#      'href': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF',
#      'id': '4V8LLVI7PbaPR0K2TGSxFF',
#      'name': 'Tyler, The Creator',
#      'type': 'artist',
#      'uri': 'spotify:artist:4V8LLVI7PbaPR0K2TGSxFF'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1U1el3k54VvEUzo3ybLPlM'},
#      'href': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM',
#      'id': '1U1el3k54VvEUzo3ybLPlM',
#      'name': 'Kali Uchis',
#      'type': 'artist',
#      'uri': 'spotify:artist:1U1el3k54VvEUzo3ybLPlM'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'MA',
#     'DZ',
#     'TN',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 180386,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USQX91701275'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7KA4W4McWYRpgf0fWsJZWB'},
#    'href': 'https://api.spotify.com/v1/tracks/7KA4W4McWYRpgf0fWsJZWB',
#    'id': '7KA4W4McWYRpgf0fWsJZWB',
#    'is_local': False,
#    'name': 'See You Again (feat. Kali Uchis)',
#    'popularity': 95,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c703198293891e3b276800ea6b187cf7951d3d7d?cid=feff654b2685484ea84ba4c1be608611',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:7KA4W4McWYRpgf0fWsJZWB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-02T10:08:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1NNRWkhwmcXRimFYSBpB1y'},
#       'href': 'https://api.spotify.com/v1/artists/1NNRWkhwmcXRimFYSBpB1y',
#       'id': '1NNRWkhwmcXRimFYSBpB1y',
#       'name': 'Yng Lvcas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1NNRWkhwmcXRimFYSBpB1y'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#       'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#       'id': '12GqGscKJx3aE4t07u7eVZ',
#       'name': 'Peso Pluma',
#       'type': 'artist',
#       'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
# ...
#      'name': 'Travis Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#      'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#      'id': '50co4Is1HCEo8bhOyUWKpn',
#      'name': 'Young Thug',
#      'type': 'artist',
#      'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 194786,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12208787'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5wG3HvLhF6Y5KTGlK0IW3J'},
#    'href': 'https://api.spotify.com/v1/tracks/5wG3HvLhF6Y5KTGlK0IW3J',
#    'id': '5wG3HvLhF6Y5KTGlK0IW3J',
#    'is_local': False,
#    'name': 'Trance (with Travis Scott & Young Thug)',
#    'popularity': 90,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5wG3HvLhF6Y5KTGlK0IW3J'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-02T10:08:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5MS3MvWHJ3lOZPLiMxzOU6'},
#     'href': 'https://api.spotify.com/v1/albums/5MS3MvWHJ3lOZPLiMxzOU6',
#     'id': '5MS3MvWHJ3lOZPLiMxzOU6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27302854a7060fccc1a66a4b5ad',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0202854a7060fccc1a66a4b5ad',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485102854a7060fccc1a66a4b5ad',
#       'width': 64}],
#     'name': 'Her Loss',
#     'release_date': '2022-11-04',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5MS3MvWHJ3lOZPLiMxzOU6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#      'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#      'id': '1URnnhqYAYcrqrcwql10ft',
#      'name': '21 Savage',
#      'type': 'artist',
#      'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 239359,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12208598'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1bDbXMyjaUIooNwFE9wn0N'},
#    'href': 'https://api.spotify.com/v1/tracks/1bDbXMyjaUIooNwFE9wn0N',
#    'id': '1bDbXMyjaUIooNwFE9wn0N',
#    'is_local': False,
#    'name': 'Rich Flex',
#    'popularity': 90,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1bDbXMyjaUIooNwFE9wn0N'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-02T10:08:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FAo7ORAHEzSSf5q10LLfN'},
#       'href': 'https://api.spotify.com/v1/artists/6FAo7ORAHEzSSf5q10LLfN',
#       'id': '6FAo7ORAHEzSSf5q10LLfN',
#       'name': 'Lil Mabu',
#       'type': 'artist',
#       'uri': 'spotify:artist:6FAo7ORAHEzSSf5q10LLfN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2na9riat7uwn9pax75cJue'},
#     'href': 'https://api.spotify.com/v1/albums/2na9riat7uwn9pax75cJue',
#     'id': '2na9riat7uwn9pax75cJue',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a56e7dc625146a33a712bef4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a56e7dc625146a33a712bef4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a56e7dc625146a33a712bef4',
#       'width': 64}],
#     'name': 'MATHEMATICAL DISRESPECT',
#     'release_date': '2023-05-05',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2na9riat7uwn9pax75cJue'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FAo7ORAHEzSSf5q10LLfN'},
#      'href': 'https://api.spotify.com/v1/artists/6FAo7ORAHEzSSf5q10LLfN',
#      'id': '6FAo7ORAHEzSSf5q10LLfN',
#      'name': 'Lil Mabu',
#      'type': 'artist',
#      'uri': 'spotify:artist:6FAo7ORAHEzSSf5q10LLfN'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 88304,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZVEM2324634'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0Ymjv0OJeIIPXr6s9wi3iW'},
#    'href': 'https://api.spotify.com/v1/tracks/0Ymjv0OJeIIPXr6s9wi3iW',
#    'id': '0Ymjv0OJeIIPXr6s9wi3iW',
#    'is_local': False,
#    'name': 'MATHEMATICAL DISRESPECT',
#    'popularity': 88,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8b5a6efd26fd97902739816fd35a3a896af7e970?cid=feff654b2685484ea84ba4c1be608611',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0Ymjv0OJeIIPXr6s9wi3iW'},
#   'video_thumbnail': {'url': None}}]

# %%
data['items'][0]['track']['album']['id']
# Out:
# '5aDEezKnOqyQo0qvTFhpkM'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'DESVELADO'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-04-28'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 16

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'name': 'DESVELADO',
#   'release_date': '2023-04-28',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'},
#  {'album_id': '6i7mF7whyRJuLJ4ogbH2wh',
#   'name': 'One Thing At A Time',
#   'release_date': '2023-03-03',
#   'total_tracks': 36,
#   'url': 'https://open.spotify.com/album/6i7mF7whyRJuLJ4ogbH2wh'},
#  {'album_id': '6ciIG1XKTlVIn0Yl8rvsce',
#   'name': 'Almost Healed',
#   'release_date': '2023-05-26',
#   'total_tracks': 21,
#   'url': 'https://open.spotify.com/album/6ciIG1XKTlVIn0Yl8rvsce'},
#  {'album_id': '5gCcb5fsSb6w5K8SyJrgtB',
#   'name': 'WHERE SHE GOES',
#   'release_date': '2023-05-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5gCcb5fsSb6w5K8SyJrgtB'},
#  {'album_id': '7aGzSSUD8S6IhPCsZSiuMT',
#   'name': 'un x100to',
#   'release_date': '2023-04-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7aGzSSUD8S6IhPCsZSiuMT'},
#  {'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'name': 'SOS',
#   'release_date': '2022-12-08',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#  {'album_id': '2nkto6YNI4rUYTLqEwWJ3o',
#   'name': 'Flower Boy',
#   'release_date': '2017-07-21',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/2nkto6YNI4rUYTLqEwWJ3o'},
#  {'album_id': '6aBVGuOUEuX18rHxyDWbti',
#   'name': 'La Bebe (Remix)',
#   'release_date': '2023-03-17',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6aBVGuOUEuX18rHxyDWbti'},
#  {'album_id': '6ciIG1XKTlVIn0Yl8rvsce',
#   'name': 'Almost Healed',
#   'release_date': '2023-05-26',
#   'total_tracks': 21,
#   'url': 'https://open.spotify.com/album/6ciIG1XKTlVIn0Yl8rvsce'},
#  {'album_id': '3GqCt85yKxtKxnIivSN15e',
#   'name': 'TQM',
#   'release_date': '2023-05-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3GqCt85yKxtKxnIivSN15e'},
#  {'album_id': '5dKPhEYBhP8j85HcxQfaw6',
#   'name': 'Peso Pluma: Bzrp Music Sessions, Vol. 55',
#   'release_date': '2023-06-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5dKPhEYBhP8j85HcxQfaw6'},
#  {'album_id': '5Uly85dJHHDfHQCsyUQ8gw',
#   'name': "Gettin' Old",
#   'release_date': '2023-03-24',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/5Uly85dJHHDfHQCsyUQ8gw'},
#  {'album_id': '6cVfHBcp3AdpYY0bBglkLN',
#   'name': "Boy's a liar Pt. 2",
#   'release_date': '2023-02-03',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6cVfHBcp3AdpYY0bBglkLN'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '5letLUZIFsQikJYShfGNs4',
#   'name': 'The Beginning: Cupid',
#   'release_date': '2023-02-24',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5letLUZIFsQikJYShfGNs4'},
#  {'album_id': '151w1FgRZfnKZA9FEcg9Z3',
#   'name': 'Midnights',
#   'release_date': '2022-10-21',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/151w1FgRZfnKZA9FEcg9Z3'},
#  {'album_id': '6uk3hBYbrMsSzufADPjv9K',
#   'name': 'Area Codes',
#   'release_date': '2023-03-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6uk3hBYbrMsSzufADPjv9K'},
#  {'album_id': '67WUCOjyl44d8fAFzHONjW',
#   'name': 'Search & Rescue',
#   'release_date': '2023-04-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/67WUCOjyl44d8fAFzHONjW'},
#  {'album_id': '6i7mF7whyRJuLJ4ogbH2wh',
#   'name': 'One Thing At A Time',
#   'release_date': '2023-03-03',
#   'total_tracks': 36,
#   'url': 'https://open.spotify.com/album/6i7mF7whyRJuLJ4ogbH2wh'},
#  {'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'name': 'Endless Summer Vacation',
#   'release_date': '2023-03-10',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'},
#  {'album_id': '2OXBosbXT7Qs3J6vBd6IkI',
#   'name': 'PRC',
#   'release_date': '2023-01-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2OXBosbXT7Qs3J6vBd6IkI'},
#  {'album_id': '1fnJ7k0bllNfL1kVdNVW1A',
#   'name': 'Midnights (The Til Dawn Edition)',
#   'release_date': '2023-05-26',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/1fnJ7k0bllNfL1kVdNVW1A'},
#  {'album_id': '5mRzjZUa5VfaveaPtPqJBB',
#   'name': 'Bye',
#   'release_date': '2023-05-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5mRzjZUa5VfaveaPtPqJBB'},
#  {'album_id': '1CmTOKCeyz1aHH04OwvTPv',
#   'name': 'Something in the Orange',
#   'release_date': '2022-04-22',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1CmTOKCeyz1aHH04OwvTPv'},
#  {'album_id': '2szyIt0ulaHnKxxyrlUCDB',
#   'name': 'El Azul',
#   'release_date': '2023-02-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2szyIt0ulaHnKxxyrlUCDB'},
#  {'album_id': '0UMMIkurRUmkruZ3KGBLtG',
#   'name': '2014 Forest Hills Drive',
#   'release_date': '2014-12-09',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/0UMMIkurRUmkruZ3KGBLtG'},
#  {'album_id': '6JlCkqkqobGirPsaleJpFr',
#   'name': 'Dangerous: The Double Album',
#   'release_date': '2021-01-08',
#   'total_tracks': 30,
#   'url': 'https://open.spotify.com/album/6JlCkqkqobGirPsaleJpFr'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': '5cH7FqB7JD5q1tJXJ7FHYu',
#   'name': 'Dance The Night (From Barbie The Album)',
#   'release_date': '2023-05-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5cH7FqB7JD5q1tJXJ7FHYu'},
#  {'album_id': '0s2sLResjP92wRavoj9k0O',
#   'name': 'AMG',
#   'release_date': '2022-11-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0s2sLResjP92wRavoj9k0O'},
#  {'album_id': '6jVg0POvGYH1Pt6lISl3ok',
#   'name': 'Say Yes To Heaven',
#   'release_date': '2023-05-19',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6jVg0POvGYH1Pt6lISl3ok'},
#  {'album_id': '7l49L64CFakYuaV4EL11sP',
#   'name': 'Cottonwood 2',
#   'release_date': '2023-04-14',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/7l49L64CFakYuaV4EL11sP'},
#  {'album_id': '6NcI39WPu4kY6Tul11nhSv',
#   'name': 'Daylight',
#   'release_date': '2023-04-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6NcI39WPu4kY6Tul11nhSv'},
#  {'album_id': '6i7mF7whyRJuLJ4ogbH2wh',
#   'name': 'One Thing At A Time',
#   'release_date': '2023-03-03',
#   'total_tracks': 36,
#   'url': 'https://open.spotify.com/album/6i7mF7whyRJuLJ4ogbH2wh'},
#  {'album_id': '7txGsnDSqVMoRl6RQ9XyZP',
#   'name': 'HEROES & VILLAINS',
#   'release_date': '2022-12-02',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7txGsnDSqVMoRl6RQ9XyZP'},
#  {'album_id': '151w1FgRZfnKZA9FEcg9Z3',
#   'name': 'Midnights',
#   'release_date': '2022-10-21',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/151w1FgRZfnKZA9FEcg9Z3'},
#  {'album_id': '5OZ44LaqZbpP3m9B3oT8br',
#   'name': 'Red Moon In Venus',
#   'release_date': '2023-03-03',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/5OZ44LaqZbpP3m9B3oT8br'},
#  {'album_id': '7txGsnDSqVMoRl6RQ9XyZP',
#   'name': 'HEROES & VILLAINS',
#   'release_date': '2022-12-02',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7txGsnDSqVMoRl6RQ9XyZP'},
#  {'album_id': '0nayxjaX54Frd7GsZq6Pbs',
#   'name': 'Rave & Roses Ultra',
#   'release_date': '2023-04-27',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/0nayxjaX54Frd7GsZq6Pbs'},
#  {'album_id': '1fnJ7k0bllNfL1kVdNVW1A',
#   'name': 'Midnights (The Til Dawn Edition)',
#   'release_date': '2023-05-26',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/1fnJ7k0bllNfL1kVdNVW1A'},
#  {'album_id': '6PBZN8cbwkqm1ERj2BGXJ1',
#   'name': 'good kid, m.A.A.d city',
#   'release_date': '2012',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/6PBZN8cbwkqm1ERj2BGXJ1'},
#  {'album_id': '69AaAkdktFGnk9POmHENkT',
#   'name': 'this is what ____ feels like (Vol. 1-4)',
#   'release_date': '2022-09-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/69AaAkdktFGnk9POmHENkT'},
#  {'album_id': '3Ks0eeH0GWpY4AU20D5HPD',
#   'name': 'Gemini Rights',
#   'release_date': '2022-07-15',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/3Ks0eeH0GWpY4AU20D5HPD'},
#  {'album_id': '493HYe7N5pleudEZRyhE7R',
#   'name': 'All I Want Is You',
#   'release_date': '2010-11-26',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/493HYe7N5pleudEZRyhE7R'},
#  {'album_id': '2FD6g8bXEn2uQMYbeqqoCg',
#   'name': 'Just Wanna Rock',
#   'release_date': '2022-10-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2FD6g8bXEn2uQMYbeqqoCg'},
#  {'album_id': '4AdZV63ycxFLF6Hcol0QnB',
#   'name': 'Starboy',
#   'release_date': '2016-11-24',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#  {'album_id': '2x4aShbWkdZ1h8sfO23yZN',
#   'name': 'AMERICA HAS A PROBLEM (feat. Kendrick Lamar)',
#   'release_date': '2023-05-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2x4aShbWkdZ1h8sfO23yZN'},
#  {'album_id': '7txGsnDSqVMoRl6RQ9XyZP',
#   'name': 'HEROES & VILLAINS',
#   'release_date': '2022-12-02',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7txGsnDSqVMoRl6RQ9XyZP'},
#  {'album_id': '5MS3MvWHJ3lOZPLiMxzOU6',
#   'name': 'Her Loss',
#   'release_date': '2022-11-04',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/5MS3MvWHJ3lOZPLiMxzOU6'},
#  {'album_id': '2na9riat7uwn9pax75cJue',
#   'name': 'MATHEMATICAL DISRESPECT',
#   'release_date': '2023-05-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2na9riat7uwn9pax75cJue'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2023-06-02T10:08:55Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#      'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#      'id': '0XeEobZplHxzM9QzFQWLiR',
#      'name': 'Eslabon Armado',
#      'type': 'artist',
#      'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'},
#    'href': 'https://api.spotify.com/v1/albums/5aDEezKnOqyQo0qvTFhpkM',
#    'id': '5aDEezKnOqyQo0qvTFhpkM',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273dfddf1cb31b85a6d28b7d91f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02dfddf1cb31b85a6d28b7d91f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851dfddf1cb31b85a6d28b7d91f',
#      'width': 64}],
#    'name': 'DESVELADO',
#    'release_date': '2023-04-28',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:5aDEezKnOqyQo0qvTFhpkM'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#     'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#     'id': '0XeEobZplHxzM9QzFQWLiR',
#     'name': 'Eslabon Armado',
#     'type': 'artist',
#     'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#     'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#     'id': '12GqGscKJx3aE4t07u7eVZ',
#     'name': 'Peso Pluma',
#     'type': 'artist',
#     'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 165671,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'USE7D2300007'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3qQbCzHBycnDpGskqOWY0E'},
#   'href': 'https://api.spotify.com/v1/tracks/3qQbCzHBycnDpGskqOWY0E',
#   'id': '3qQbCzHBycnDpGskqOWY0E',
#   'is_local': False,
#   'name': 'Ella Baila Sola',
#   'popularity': 92,
#   'preview_url': 'https://p.scdn.co/mp3-preview/5d39f3e17f1e20e2711d033001e48b8d4249b992?cid=feff654b2685484ea84ba4c1be608611',
#   'track': True,
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:3qQbCzHBycnDpGskqOWY0E'},
#  'video_thumbnail': {'url': None}}

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'external_url': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '3hcs9uc56yIGFCSy9leWe7',
#   'artist_name': 'Lil Durk',
#   'external_url': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7'},
#  {'artist_id': '6l3HvQ5sa6mXTsMTB19rO5',
#   'artist_name': 'J. Cole',
#   'external_url': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '6XkjpgcEsYab502Vr1bBeW',
#   'artist_name': 'Grupo Frontera',
#   'external_url': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'external_url': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '1U1el3k54VvEUzo3ybLPlM',
#   'artist_name': 'Kali Uchis',
#   'external_url': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM'},
#  {'artist_id': '1NNRWkhwmcXRimFYSBpB1y',
#   'artist_name': 'Yng Lvcas',
#   'external_url': 'https://api.spotify.com/v1/artists/1NNRWkhwmcXRimFYSBpB1y'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '3hcs9uc56yIGFCSy9leWe7',
#   'artist_name': 'Lil Durk',
#   'external_url': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'external_url': 'https://api.spotify.com/v1/artists/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '716NhGYqD1jl2wI1Qkgq36',
#   'artist_name': 'Bizarrap',
#   'external_url': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '718COspgdWOnwOFpJHRZHS',
#   'artist_name': 'Luke Combs',
#   'external_url': 'https://api.spotify.com/v1/artists/718COspgdWOnwOFpJHRZHS'},
#  {'artist_id': '78rUTD7y6Cy67W1RVzYs7t',
#   'artist_name': 'PinkPantheress',
#   'external_url': 'https://api.spotify.com/v1/artists/78rUTD7y6Cy67W1RVzYs7t'},
#  {'artist_id': '3LZZPxNDGDFVSIPqf4JuEf',
#   'artist_name': 'Ice Spice',
#   'external_url': 'https://api.spotify.com/v1/artists/3LZZPxNDGDFVSIPqf4JuEf'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '4GJ6xDCF5jaUqD6avOuQT6',
#   'artist_name': 'FIFTY FIFTY',
#   'external_url': 'https://api.spotify.com/v1/artists/4GJ6xDCF5jaUqD6avOuQT6'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '1YRqgFNXqRyMDRr8ClS1NL',
#   'artist_name': 'Kali',
#   'external_url': 'https://api.spotify.com/v1/artists/1YRqgFNXqRyMDRr8ClS1NL'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'external_url': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '5YGY8feqx7naU7z4HrwZM6',
#   'artist_name': 'Miley Cyrus',
#   'external_url': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '0elWFr7TW8piilVRYJUe4P',
#   'artist_name': 'Natanael Cano',
#   'external_url': 'https://api.spotify.com/v1/artists/0elWFr7TW8piilVRYJUe4P'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'artist_name': 'Zach Bryan',
#   'external_url': 'https://api.spotify.com/v1/artists/40ZNYROS4zLfyyBSs2PGe2'},
#  {'artist_id': '7Gi6gjaWy3DxyilpF1a8Is',
#   'artist_name': 'Junior H',
#   'external_url': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '6l3HvQ5sa6mXTsMTB19rO5',
#   'artist_name': 'J. Cole',
#   'external_url': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'external_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'artist_name': 'Dua Lipa',
#   'external_url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '0elWFr7TW8piilVRYJUe4P',
#   'artist_name': 'Natanael Cano',
#   'external_url': 'https://api.spotify.com/v1/artists/0elWFr7TW8piilVRYJUe4P'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '6Sbl0NT50roqWvy746MfVf',
#   'artist_name': 'Gabito Ballesteros',
#   'external_url': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf'},
#  {'artist_id': '00FQb4jTyendYWaN8pK0wa',
#   'artist_name': 'Lana Del Rey',
#   'external_url': 'https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa'},
#  {'artist_id': '0ErzCpIMyLcjPiwT4elrtZ',
#   'artist_name': 'NLE Choppa',
#   'external_url': 'https://api.spotify.com/v1/artists/0ErzCpIMyLcjPiwT4elrtZ'},
#  {'artist_id': '33NVpKoXjItPwUJTMZIOiY',
#   'artist_name': 'David Kushner',
#   'external_url': 'https://api.spotify.com/v1/artists/33NVpKoXjItPwUJTMZIOiY'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '0iEtIxbK0KxaSlF7G42ZOp',
#   'artist_name': 'Metro Boomin',
#   'external_url': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '1URnnhqYAYcrqrcwql10ft',
#   'artist_name': '21 Savage',
#   'external_url': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '1U1el3k54VvEUzo3ybLPlM',
#   'artist_name': 'Kali Uchis',
#   'external_url': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM'},
#  {'artist_id': '0iEtIxbK0KxaSlF7G42ZOp',
#   'artist_name': 'Metro Boomin',
#   'external_url': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '7bXgB6jMjp9ATFy66eO08Z',
#   'artist_name': 'Chris Brown',
#   'external_url': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z'},
#  {'artist_id': '46pWGuE3dSwY3bMMXGBvVS',
#   'artist_name': 'Rema',
#   'external_url': 'https://api.spotify.com/v1/artists/46pWGuE3dSwY3bMMXGBvVS'},
#  {'artist_id': '0C8ZW7ezQVs4URX5aX7Kqx',
#   'artist_name': 'Selena Gomez',
#   'external_url': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '3LZZPxNDGDFVSIPqf4JuEf',
#   'artist_name': 'Ice Spice',
#   'external_url': 'https://api.spotify.com/v1/artists/3LZZPxNDGDFVSIPqf4JuEf'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '28ExwzUQsvgJooOI0X1mr3',
#   'artist_name': 'Jay Rock',
#   'external_url': 'https://api.spotify.com/v1/artists/28ExwzUQsvgJooOI0X1mr3'},
#  {'artist_id': '164Uj4eKjl6zTBKfJLFKKK',
#   'artist_name': 'JVKE',
#   'external_url': 'https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK'},
#  {'artist_id': '57vWImR43h4CaDao012Ofp',
#   'artist_name': 'Steve Lacy',
#   'external_url': 'https://api.spotify.com/v1/artists/57vWImR43h4CaDao012Ofp'},
#  {'artist_id': '360IAlyVv4PCEVjgyMZrxK',
#   'artist_name': 'Miguel',
#   'external_url': 'https://api.spotify.com/v1/artists/360IAlyVv4PCEVjgyMZrxK'},
#  {'artist_id': '4O15NlyKLIASxsJ0PrXPfz',
#   'artist_name': 'Lil Uzi Vert',
#   'external_url': 'https://api.spotify.com/v1/artists/4O15NlyKLIASxsJ0PrXPfz'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '6vWDO969PvNqNYHIOW5v0m',
#   'artist_name': 'Beyoncé',
#   'external_url': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '0iEtIxbK0KxaSlF7G42ZOp',
#   'artist_name': 'Metro Boomin',
#   'external_url': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '50co4Is1HCEo8bhOyUWKpn',
#   'artist_name': 'Young Thug',
#   'external_url': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'external_url': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '1URnnhqYAYcrqrcwql10ft',
#   'artist_name': '21 Savage',
#   'external_url': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft'},
#  {'artist_id': '6FAo7ORAHEzSSf5q10LLfN',
#   'artist_name': 'Lil Mabu',
#   'external_url': 'https://api.spotify.com/v1/artists/6FAo7ORAHEzSSf5q10LLfN'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '3qQbCzHBycnDpGskqOWY0E',
#   'song_name': 'Ella Baila Sola',
#   'duration_ms': 165671,
#   'url': 'https://open.spotify.com/track/3qQbCzHBycnDpGskqOWY0E',
#   'popularity': 92,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'artist_id': '0XeEobZplHxzM9QzFQWLiR'},
#  {'song_id': '7K3BhSpAxZBznislvUMVtn',
#   'song_name': 'Last Night',
#   'duration_ms': 163854,
#   'url': 'https://open.spotify.com/track/7K3BhSpAxZBznislvUMVtn',
#   'popularity': 89,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6i7mF7whyRJuLJ4ogbH2wh',
#   'artist_id': '4oUHIQIBe0LHzYfvXNW4QM'},
#  {'song_id': '6T7FXSuXykeGktMLGp8WgE',
#   'song_name': 'All My Life (feat. J. Cole)',
#   'duration_ms': 223878,
#   'url': 'https://open.spotify.com/track/6T7FXSuXykeGktMLGp8WgE',
#   'popularity': 82,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6ciIG1XKTlVIn0Yl8rvsce',
#   'artist_id': '3hcs9uc56yIGFCSy9leWe7'},
#  {'song_id': '7ro0hRteUMfnOioTFI5TG1',
#   'song_name': 'WHERE SHE GOES',
#   'duration_ms': 231704,
#   'url': 'https://open.spotify.com/track/7ro0hRteUMfnOioTFI5TG1',
#   'popularity': 95,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '5gCcb5fsSb6w5K8SyJrgtB',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '6pD0ufEQq0xdHSsRbg9LBK',
#   'song_name': 'un x100to',
#   'duration_ms': 194563,
#   'url': 'https://open.spotify.com/track/6pD0ufEQq0xdHSsRbg9LBK',
#   'popularity': 100,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '7aGzSSUD8S6IhPCsZSiuMT',
#   'artist_id': '6XkjpgcEsYab502Vr1bBeW'},
#  {'song_id': '1Qrg8KqiBpW07V7PNxwwwL',
#   'song_name': 'Kill Bill',
#   'duration_ms': 153946,
#   'url': 'https://open.spotify.com/track/1Qrg8KqiBpW07V7PNxwwwL',
#   'popularity': 94,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'},
#  {'song_id': '7KA4W4McWYRpgf0fWsJZWB',
#   'song_name': 'See You Again (feat. Kali Uchis)',
#   'duration_ms': 180386,
#   'url': 'https://open.spotify.com/track/7KA4W4McWYRpgf0fWsJZWB',
#   'popularity': 95,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '2nkto6YNI4rUYTLqEwWJ3o',
#   'artist_id': '4V8LLVI7PbaPR0K2TGSxFF'},
#  {'song_id': '2UW7JaomAMuX9pZrjVpHAU',
#   'song_name': 'La Bebe - Remix',
#   'duration_ms': 234352,
#   'url': 'https://open.spotify.com/track/2UW7JaomAMuX9pZrjVpHAU',
#   'popularity': 99,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6aBVGuOUEuX18rHxyDWbti',
#   'artist_id': '1NNRWkhwmcXRimFYSBpB1y'},
#  {'song_id': '1fXnu2HzxbDtoyvFPWG3Bw',
#   'song_name': 'Stand By Me (feat. Morgan Wallen)',
#   'duration_ms': 219173,
#   'url': 'https://open.spotify.com/track/1fXnu2HzxbDtoyvFPWG3Bw',
#   'popularity': 83,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6ciIG1XKTlVIn0Yl8rvsce',
#   'artist_id': '3hcs9uc56yIGFCSy9leWe7'},
#  {'song_id': '368eeEO3Y2uZUQ6S5oIjcu',
#   'song_name': 'TQM',
#   'duration_ms': 158965,
#   'url': 'https://open.spotify.com/track/368eeEO3Y2uZUQ6S5oIjcu',
#   'popularity': 89,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '3GqCt85yKxtKxnIivSN15e',
#   'artist_id': '0ys2OFYzWYB5hRDLCsBqxt'},
#  {'song_id': '5AqiaZwhmC6dIbgWrD5SzV',
#   'song_name': 'Peso Pluma: Bzrp Music Sessions, Vol. 55',
#   'duration_ms': 188361,
#   'url': 'https://open.spotify.com/track/5AqiaZwhmC6dIbgWrD5SzV',
#   'popularity': 0,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '5dKPhEYBhP8j85HcxQfaw6',
#   'artist_id': '716NhGYqD1jl2wI1Qkgq36'},
#  {'song_id': '1Lo0QY9cvc8sUB2vnIOxDT',
#   'song_name': 'Fast Car',
#   'duration_ms': 265493,
#   'url': 'https://open.spotify.com/track/1Lo0QY9cvc8sUB2vnIOxDT',
#   'popularity': 89,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '5Uly85dJHHDfHQCsyUQ8gw',
#   'artist_id': '718COspgdWOnwOFpJHRZHS'},
#  {'song_id': '6AQbmUe0Qwf5PZnt4HmTXv',
#   'song_name': "Boy's a Liar Pt. 2",
#   'duration_ms': 131013,
#   'url': 'https://open.spotify.com/track/6AQbmUe0Qwf5PZnt4HmTXv',
#   'popularity': 95,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6cVfHBcp3AdpYY0bBglkLN',
#   'artist_id': '78rUTD7y6Cy67W1RVzYs7t'},
#  {'song_id': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'song_name': 'Cruel Summer',
#   'duration_ms': 178426,
#   'url': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr',
#   'popularity': 93,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '7FbrGaHYVDmfr7KoLIZnQ7',
#   'song_name': 'Cupid - Twin Ver.',
#   'duration_ms': 174253,
#   'url': 'https://open.spotify.com/track/7FbrGaHYVDmfr7KoLIZnQ7',
#   'popularity': 98,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '5letLUZIFsQikJYShfGNs4',
#   'artist_id': '4GJ6xDCF5jaUqD6avOuQT6'},
#  {'song_id': '0V3wPSX9ygBnCm8psDIegu',
#   'song_name': 'Anti-Hero',
#   'duration_ms': 200690,
#   'url': 'https://open.spotify.com/track/0V3wPSX9ygBnCm8psDIegu',
#   'popularity': 94,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '151w1FgRZfnKZA9FEcg9Z3',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '7sliFe6W30tPBPh6dvZsIH',
#   'song_name': 'Area Codes',
#   'duration_ms': 139325,
#   'url': 'https://open.spotify.com/track/7sliFe6W30tPBPh6dvZsIH',
#   'popularity': 87,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6uk3hBYbrMsSzufADPjv9K',
#   'artist_id': '1YRqgFNXqRyMDRr8ClS1NL'},
#  {'song_id': '7aRCf5cLOFN1U7kvtChY1G',
#   'song_name': 'Search & Rescue',
#   'duration_ms': 272112,
#   'url': 'https://open.spotify.com/track/7aRCf5cLOFN1U7kvtChY1G',
#   'popularity': 91,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '67WUCOjyl44d8fAFzHONjW',
#   'artist_id': '3TVXtAsR1Inumwj472S9r4'},
#  {'song_id': '5W4kiM2cUYBJXKRudNyxjW',
#   'song_name': 'You Proof',
#   'duration_ms': 157477,
#   'url': 'https://open.spotify.com/track/5W4kiM2cUYBJXKRudNyxjW',
#   'popularity': 86,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6i7mF7whyRJuLJ4ogbH2wh',
#   'artist_id': '4oUHIQIBe0LHzYfvXNW4QM'},
#  {'song_id': '4DHcnVTT87F0zZhRPYmZ3B',
#   'song_name': 'Flowers',
#   'duration_ms': 200600,
#   'url': 'https://open.spotify.com/track/4DHcnVTT87F0zZhRPYmZ3B',
#   'popularity': 91,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'artist_id': '5YGY8feqx7naU7z4HrwZM6'},
#  {'song_id': '2mpoNBkngUEwnaKoBhZ0vl',
#   'song_name': 'PRC',
#   'duration_ms': 184066,
#   'url': 'https://open.spotify.com/track/2mpoNBkngUEwnaKoBhZ0vl',
#   'popularity': 95,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '2OXBosbXT7Qs3J6vBd6IkI',
#   'artist_id': '12GqGscKJx3aE4t07u7eVZ'},
#  {'song_id': '3xYJScVfxByb61dYHTwiby',
#   'song_name': 'Hits Different',
#   'duration_ms': 234466,
#   'url': 'https://open.spotify.com/track/3xYJScVfxByb61dYHTwiby',
#   'popularity': 84,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '1fnJ7k0bllNfL1kVdNVW1A',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '6n2P81rPk2RTzwnNNgFOdb',
#   'song_name': 'Bye',
#   'duration_ms': 212976,
#   'url': 'https://open.spotify.com/track/6n2P81rPk2RTzwnNNgFOdb',
#   'popularity': 81,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '5mRzjZUa5VfaveaPtPqJBB',
#   'artist_id': '12GqGscKJx3aE4t07u7eVZ'},
#  {'song_id': '3WMj8moIAXJhHsyLaqIIHI',
#   'song_name': 'Something in the Orange',
#   'duration_ms': 228013,
#   'url': 'https://open.spotify.com/track/3WMj8moIAXJhHsyLaqIIHI',
#   'popularity': 88,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '1CmTOKCeyz1aHH04OwvTPv',
#   'artist_id': '40ZNYROS4zLfyyBSs2PGe2'},
#  {'song_id': '1haJsMtoBhHfvuM7XWuT3W',
#   'song_name': 'El Azul',
#   'duration_ms': 187225,
#   'url': 'https://open.spotify.com/track/1haJsMtoBhHfvuM7XWuT3W',
#   'popularity': 95,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '2szyIt0ulaHnKxxyrlUCDB',
#   'artist_id': '7Gi6gjaWy3DxyilpF1a8Is'},
#  {'song_id': '68Dni7IE4VyPkTOH9mRWHr',
#   'song_name': 'No Role Modelz',
#   'duration_ms': 292799,
#   'url': 'https://open.spotify.com/track/68Dni7IE4VyPkTOH9mRWHr',
#   'popularity': 91,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '0UMMIkurRUmkruZ3KGBLtG',
#   'artist_id': '6l3HvQ5sa6mXTsMTB19rO5'},
#  {'song_id': '3cBsEDNhFI9E82vPj3kvi3',
#   'song_name': 'Wasted On You',
#   'duration_ms': 178520,
#   'url': 'https://open.spotify.com/track/3cBsEDNhFI9E82vPj3kvi3',
#   'popularity': 87,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6JlCkqkqobGirPsaleJpFr',
#   'artist_id': '4oUHIQIBe0LHzYfvXNW4QM'},
#  {'song_id': '4Dvkj6JhhA12EX05fT7y2e',
#   'song_name': 'As It Was',
#   'duration_ms': 167303,
#   'url': 'https://open.spotify.com/track/4Dvkj6JhhA12EX05fT7y2e',
#   'popularity': 92,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'artist_id': '6KImCVD70vtIoJWnq6nGn3'},
#  {'song_id': '1vYXt7VSjH9JIM5oRRo7vA',
#   'song_name': 'Dance The Night (From Barbie The Album)',
#   'duration_ms': 176579,
#   'url': 'https://open.spotify.com/track/1vYXt7VSjH9JIM5oRRo7vA',
#   'popularity': 85,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '5cH7FqB7JD5q1tJXJ7FHYu',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we'},
#  {'song_id': '1lRtH4FszTrwwlK5gTSbXO',
#   'song_name': 'AMG',
#   'duration_ms': 174942,
#   'url': 'https://open.spotify.com/track/1lRtH4FszTrwwlK5gTSbXO',
#   'popularity': 94,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '0s2sLResjP92wRavoj9k0O',
#   'artist_id': '0elWFr7TW8piilVRYJUe4P'},
#  {'song_id': '6GGtHZgBycCgGBUhZo81xe',
#   'song_name': 'Say Yes To Heaven',
#   'duration_ms': 209156,
#   'url': 'https://open.spotify.com/track/6GGtHZgBycCgGBUhZo81xe',
#   'popularity': 90,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6jVg0POvGYH1Pt6lISl3ok',
#   'artist_id': '00FQb4jTyendYWaN8pK0wa'},
#  {'song_id': '0WoVfPjxsf9MTvPt9ptqeE',
#   'song_name': 'SLUT ME OUT',
#   'duration_ms': 123672,
#   'url': 'https://open.spotify.com/track/0WoVfPjxsf9MTvPt9ptqeE',
#   'popularity': 76,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '7l49L64CFakYuaV4EL11sP',
#   'artist_id': '0ErzCpIMyLcjPiwT4elrtZ'},
#  {'song_id': '1odExI7RdWc4BT515LTAwj',
#   'song_name': 'Daylight',
#   'duration_ms': 212953,
#   'url': 'https://open.spotify.com/track/1odExI7RdWc4BT515LTAwj',
#   'popularity': 97,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6NcI39WPu4kY6Tul11nhSv',
#   'artist_id': '33NVpKoXjItPwUJTMZIOiY'},
#  {'song_id': '0PAcdVzhPO4gq1Iym9ESnK',
#   'song_name': 'Thinkin’ Bout Me',
#   'duration_ms': 177387,
#   'url': 'https://open.spotify.com/track/0PAcdVzhPO4gq1Iym9ESnK',
#   'popularity': 87,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6i7mF7whyRJuLJ4ogbH2wh',
#   'artist_id': '4oUHIQIBe0LHzYfvXNW4QM'},
#  {'song_id': '2dHHgzDwk4BJdRwy9uXhTO',
#   'song_name': "Creepin' (with The Weeknd & 21 Savage)",
#   'duration_ms': 221520,
#   'url': 'https://open.spotify.com/track/2dHHgzDwk4BJdRwy9uXhTO',
#   'popularity': 96,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '7txGsnDSqVMoRl6RQ9XyZP',
#   'artist_id': '0iEtIxbK0KxaSlF7G42ZOp'},
#  {'song_id': '7KokYm8cMIXCsGVmUvKtqf',
#   'song_name': 'Karma',
#   'duration_ms': 204852,
#   'url': 'https://open.spotify.com/track/7KokYm8cMIXCsGVmUvKtqf',
#   'popularity': 88,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '151w1FgRZfnKZA9FEcg9Z3',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '0JmnkIqdlnUzPaf8sqBRs3',
#   'song_name': 'Moonlight',
#   'duration_ms': 187723,
#   'url': 'https://open.spotify.com/track/0JmnkIqdlnUzPaf8sqBRs3',
#   'popularity': 87,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '5OZ44LaqZbpP3m9B3oT8br',
#   'artist_id': '1U1el3k54VvEUzo3ybLPlM'},
#  {'song_id': '0vjeOZ3Ft5jvAi9SBFJm1j',
#   'song_name': 'Superhero (Heroes & Villains) [with Future & Chris Brown]',
#   'duration_ms': 182666,
#   'url': 'https://open.spotify.com/track/0vjeOZ3Ft5jvAi9SBFJm1j',
#   'popularity': 90,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '7txGsnDSqVMoRl6RQ9XyZP',
#   'artist_id': '0iEtIxbK0KxaSlF7G42ZOp'},
#  {'song_id': '1s7oOCT8vauUh01PbJD6ps',
#   'song_name': 'Calm Down (with Selena Gomez)',
#   'duration_ms': 239317,
#   'url': 'https://open.spotify.com/track/1s7oOCT8vauUh01PbJD6ps',
#   'popularity': 80,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '0nayxjaX54Frd7GsZq6Pbs',
#   'artist_id': '46pWGuE3dSwY3bMMXGBvVS'},
#  {'song_id': '4i6cwNY6oIUU2XZxPIw82Y',
#   'song_name': 'Karma (feat. Ice Spice)',
#   'duration_ms': 201493,
#   'url': 'https://open.spotify.com/track/4i6cwNY6oIUU2XZxPIw82Y',
#   'popularity': 83,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '1fnJ7k0bllNfL1kVdNVW1A',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '2HbKqm4o0w5wEeEFXm2sD4',
#   'song_name': 'Money Trees',
#   'duration_ms': 386906,
#   'url': 'https://open.spotify.com/track/2HbKqm4o0w5wEeEFXm2sD4',
#   'popularity': 85,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '6PBZN8cbwkqm1ERj2BGXJ1',
#   'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'song_id': '5odlY52u43F5BjByhxg7wg',
#   'song_name': 'golden hour',
#   'duration_ms': 209259,
#   'url': 'https://open.spotify.com/track/5odlY52u43F5BjByhxg7wg',
#   'popularity': 90,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '69AaAkdktFGnk9POmHENkT',
#   'artist_id': '164Uj4eKjl6zTBKfJLFKKK'},
#  {'song_id': '4k6Uh1HXdhtusDW5y8Gbvy',
#   'song_name': 'Bad Habit',
#   'duration_ms': 232066,
#   'url': 'https://open.spotify.com/track/4k6Uh1HXdhtusDW5y8Gbvy',
#   'popularity': 85,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '3Ks0eeH0GWpY4AU20D5HPD',
#   'artist_id': '57vWImR43h4CaDao012Ofp'},
#  {'song_id': '0JXXNGljqupsJaZsgSbMZV',
#   'song_name': 'Sure Thing',
#   'duration_ms': 195373,
#   'url': 'https://open.spotify.com/track/0JXXNGljqupsJaZsgSbMZV',
#   'popularity': 91,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '493HYe7N5pleudEZRyhE7R',
#   'artist_id': '360IAlyVv4PCEVjgyMZrxK'},
#  {'song_id': '4FyesJzVpA39hbYvcseO2d',
#   'song_name': 'Just Wanna Rock',
#   'duration_ms': 123890,
#   'url': 'https://open.spotify.com/track/4FyesJzVpA39hbYvcseO2d',
#   'popularity': 90,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '2FD6g8bXEn2uQMYbeqqoCg',
#   'artist_id': '4O15NlyKLIASxsJ0PrXPfz'},
#  {'song_id': '2LBqCSwhJGcFQeTHMVGwy3',
#   'song_name': 'Die For You',
#   'duration_ms': 260253,
#   'url': 'https://open.spotify.com/track/2LBqCSwhJGcFQeTHMVGwy3',
#   'popularity': 91,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '4AdZV63ycxFLF6Hcol0QnB',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '6l8mgVN9Xf1hiDIFGA6CTE',
#   'song_name': 'AMERICA HAS A PROBLEM (feat. Kendrick Lamar)',
#   'duration_ms': 260962,
#   'url': 'https://open.spotify.com/track/6l8mgVN9Xf1hiDIFGA6CTE',
#   'popularity': 84,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '2x4aShbWkdZ1h8sfO23yZN',
#   'artist_id': '6vWDO969PvNqNYHIOW5v0m'},
#  {'song_id': '5wG3HvLhF6Y5KTGlK0IW3J',
#   'song_name': 'Trance (with Travis Scott & Young Thug)',
#   'duration_ms': 194786,
#   'url': 'https://open.spotify.com/track/5wG3HvLhF6Y5KTGlK0IW3J',
#   'popularity': 90,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '7txGsnDSqVMoRl6RQ9XyZP',
#   'artist_id': '0iEtIxbK0KxaSlF7G42ZOp'},
#  {'song_id': '1bDbXMyjaUIooNwFE9wn0N',
#   'song_name': 'Rich Flex',
#   'duration_ms': 239359,
#   'url': 'https://open.spotify.com/track/1bDbXMyjaUIooNwFE9wn0N',
#   'popularity': 90,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '5MS3MvWHJ3lOZPLiMxzOU6',
#   'artist_id': '3TVXtAsR1Inumwj472S9r4'},
#  {'song_id': '0Ymjv0OJeIIPXr6s9wi3iW',
#   'song_name': 'MATHEMATICAL DISRESPECT',
#   'duration_ms': 88304,
#   'url': 'https://open.spotify.com/track/0Ymjv0OJeIIPXr6s9wi3iW',
#   'popularity': 88,
#   'song_added': '2023-06-02T10:08:55Z',
#   'album_id': '2na9riat7uwn9pax75cJue',
#   'artist_id': '6FAo7ORAHEzSSf5q10LLfN'}]

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                 name release_date  total_tracks  \
# 0  5aDEezKnOqyQo0qvTFhpkM            DESVELADO   2023-04-28            16
# 1  6i7mF7whyRJuLJ4ogbH2wh  One Thing At A Time   2023-03-03            36
# 2  6ciIG1XKTlVIn0Yl8rvsce        Almost Healed   2023-05-26            21
# 3  5gCcb5fsSb6w5K8SyJrgtB       WHERE SHE GOES   2023-05-18             1
# 4  7aGzSSUD8S6IhPCsZSiuMT            un x100to   2023-04-17             1
#
#                                                  url
# 0  https://open.spotify.com/album/5aDEezKnOqyQo0q...
# 1  https://open.spotify.com/album/6i7mF7whyRJuLJ4...
# 2  https://open.spotify.com/album/6ciIG1XKTlVIn0Y...
# 3  https://open.spotify.com/album/5gCcb5fsSb6w5K8...
# 4  https://open.spotify.com/album/7aGzSSUD8S6IhPC...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                    song_name  duration_ms  \
# 0  3qQbCzHBycnDpGskqOWY0E              Ella Baila Sola       165671
# 1  7K3BhSpAxZBznislvUMVtn                   Last Night       163854
# 2  6T7FXSuXykeGktMLGp8WgE  All My Life (feat. J. Cole)       223878
# 3  7ro0hRteUMfnOioTFI5TG1               WHERE SHE GOES       231704
# 4  6pD0ufEQq0xdHSsRbg9LBK                    un x100to       194563
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/3qQbCzHBycnDpGs...          92
# 1  https://open.spotify.com/track/7K3BhSpAxZBznis...          89
# 2  https://open.spotify.com/track/6T7FXSuXykeGktM...          82
# 3  https://open.spotify.com/track/7ro0hRteUMfnOio...          95
# 4  https://open.spotify.com/track/6pD0ufEQq0xdHSs...         100
#
#              song_added                album_id               artist_id
# 0  2023-06-02T10:08:55Z  5aDEezKnOqyQo0qvTFhpkM  0XeEobZplHxzM9QzFQWLiR
# 1  2023-06-02T10:08:55Z  6i7mF7whyRJuLJ4ogbH2wh  4oUHIQIBe0LHzYfvXNW4QM
# 2  2023-06-02T10:08:55Z  6ciIG1XKTlVIn0Yl8rvsce  3hcs9uc56yIGFCSy9leWe7
# 3  2023-06-02T10:08:55Z  5gCcb5fsSb6w5K8SyJrgtB  4q3ewBCX7sLwd24euuV69X
# 4  2023-06-02T10:08:55Z  7aGzSSUD8S6IhPCsZSiuMT  6XkjpgcEsYab502Vr1bBeW

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
# 1  12GqGscKJx3aE4t07u7eVZ      Peso Pluma
# 2  4oUHIQIBe0LHzYfvXNW4QM   Morgan Wallen
# 3  3hcs9uc56yIGFCSy9leWe7        Lil Durk
# 4  6l3HvQ5sa6mXTsMTB19rO5         J. Cole
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0XeEobZplHx...
# 1  https://api.spotify.com/v1/artists/12GqGscKJx3...
# 2  https://api.spotify.com/v1/artists/4oUHIQIBe0L...
# 3  https://api.spotify.com/v1/artists/3hcs9uc56yI...
# 4  https://api.spotify.com/v1/artists/6l3HvQ5sa6m...

# %%
album_df.head()
# Out:
#                  album_id                 name release_date  total_tracks  \
# 0  5aDEezKnOqyQo0qvTFhpkM            DESVELADO   2023-04-28            16
# 1  6i7mF7whyRJuLJ4ogbH2wh  One Thing At A Time   2023-03-03            36
# 2  6ciIG1XKTlVIn0Yl8rvsce        Almost Healed   2023-05-26            21
# 3  5gCcb5fsSb6w5K8SyJrgtB       WHERE SHE GOES   2023-05-18             1
# 4  7aGzSSUD8S6IhPCsZSiuMT            un x100to   2023-04-17             1
#
#                                                  url
# 0  https://open.spotify.com/album/5aDEezKnOqyQo0q...
# 1  https://open.spotify.com/album/6i7mF7whyRJuLJ4...
# 2  https://open.spotify.com/album/6ciIG1XKTlVIn0Y...
# 3  https://open.spotify.com/album/5gCcb5fsSb6w5K8...
# 4  https://open.spotify.com/album/7aGzSSUD8S6IhPC...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
